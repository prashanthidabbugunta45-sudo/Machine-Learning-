# %%
plt.figure(figsize=(6, 4))

sns.scatterplot(
    data=df,
    x="CGPA",
    y="AttendancePercent"
)

plt.title("CGPA vs Attendance Percentage")
plt.xlabel("CGPA")
plt.ylabel("Attendance Percentage")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3188/2816438964.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(6, 4))
#       2
#       3 sns.scatterplot(
#       4     data=df,
#       5     x="CGPA",
#
# NameError: name 'plt' is not defined
