# %%
print("\nDataset shape:")
print(df.shape)

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3188/1073403374.py in <cell line: 0>()
#       1 print("\nDataset shape:")
# ----> 2 print(df.shape)
#       3
#       4 print("\nMissing values:")
#       5 print(df.isnull().sum())
#
# NameError: name 'df' is not defined
